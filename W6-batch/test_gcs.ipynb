# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[*]").appName("gcs-test").getOrCreate()
print(spark.sparkContext.uiWebUrl)

df = spark.read.parquet("gs://zoomcamp-486023-homework6/yellow_tripdata_2025-11.parquet")
df.limit(5).show()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/opt/conda/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/jovyan/.ivy2.5.2/cache
# The jars for the packages stored in: /home/jovyan/.ivy2.5.2/jars
# com.google.cloud.bigdataoss#gcs-connector added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-b2a32b67-6b54-4007-9e14-a8b7971b3d60;1.0
# 	confs: [default]
# 	found com.google.cloud.bigdataoss#gcs-connector;hadoop3-2.2.27 in central
# 	found com.google.api-client#google-api-client-jackson2;2.0.1 in central
# 	found com.google.api-client#google-api-client;2.0.1 in central
# 	found com.google.oauth-client#google-oauth-client;1.34.1 in central
# 	found com.google.http-client#google-http-client;1.42.3 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.15 in central
# 	found commons-logging#commons-logging;1.2 in central
# 	found commons-codec#commons-codec;1.15 in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found com.google.errorprone#error_prone_annotations;2.16 in central
# 	found com.google.guava#guava;33.1.0-jre in central
# 	found com.google.guava#failureaccess;1.0.2 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found org.checkerframework#checker-qual;3.42.0 in central
# 	found com.google.j2objc#j2objc-annotations;1.3 in central
# 	found io.opencensus#opencensus-api;0.31.1 in central
# 	found io.grpc#grpc-context;1.67.1 in central
# 	found io.opencensus#opencensus-contrib-http-util;0.31.1 in central
# 	found com.google.http-client#google-http-client-gson;1.42.3 in central
# 	found com.google.code.gson#gson;2.8.9 in central
# 	found io.grpc#grpc-api;1.67.1 in central
# 	found com.google.http-client#google-http-client-apache-v2;1.42.3 in central
# 	found com.google.cloud.bigdataoss#util;2.2.27 in central
# 	found com.google.http-client#google-http-client-jackson2;1.42.3 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.13.4 in central
# 	found com.google.apis#google-api-services-iamcredentials;v1-rev20211203-2.0.0 in central
# 	found com.google.apis#google-api-services-storage;v1-rev20240105-2.0.0 in central
# 	found com.google.api-client#google-api-client;2.2.0 in central
# 	found org.apache.httpcomponents#httpcore;4.4.16 in central
# 	found com.google.auto.value#auto-value-annotations;1.10.4 in central
# 	found com.google.auth#google-auth-library-oauth2-http;1.29.0 in central
# 	found com.google.auth#google-auth-library-credentials;1.29.0 in central
# 	found com.google.http-client#google-http-client;1.45.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.34.0 in central
# 	found com.google.j2objc#j2objc-annotations;3.0.0 in central
# 	found com.google.http-client#google-http-client-gson;1.45.0 in central
# 	found com.google.flogger#google-extensions;0.7.1 in central
# 	found com.google.flogger#flogger;0.7.1 in central
# 	found org.checkerframework#checker-compat-qual;2.5.3 in central
# 	found com.google.flogger#flogger-system-backend;0.7.1 in central
# 	found com.google.cloud.bigdataoss#util-hadoop;hadoop3-2.2.27 in central
# 	found com.google.cloud.bigdataoss#gcsio;2.2.27 in central
# 	found io.grpc#grpc-alts;1.67.1 in central
# 	found io.grpc#grpc-auth;1.67.1 in central
# 	found io.grpc#grpc-core;1.67.1 in central
# 	found io.grpc#grpc-grpclb;1.67.1 in central
# 	found io.grpc#grpc-protobuf;1.67.1 in central
# 	found com.google.protobuf#protobuf-java;3.25.3 in central
# 	found com.google.api.grpc#proto-google-common-protos;2.41.0 in central
# 	found io.grpc#grpc-stub;1.67.1 in central
# 	found org.conscrypt#conscrypt-openjdk-uber;2.5.2 in central
# 	found io.grpc#grpc-netty-shaded;1.67.1 in central
# 	found io.grpc#grpc-census;1.67.1 in central
# 	found com.google.cloud#google-cloud-storage;2.44.1 in central
# 	found com.google.errorprone#error_prone_annotations;2.35.1 in central
# 	found com.google.api-client#google-api-client;2.7.0 in central
# 	found commons-codec#commons-codec;1.17.1 in central
# 	found com.google.http-client#google-http-client-apache-v2;1.45.0 in central
# 	found com.google.cloud#google-cloud-core;2.44.1 in central
# 	found com.google.protobuf#protobuf-java-util;3.25.3 in central
# 	found com.google.api.grpc#proto-google-iam-v1;1.1.7 in central
# 	found org.threeten#threetenbp;1.7.0 in central
# 	found com.google.cloud#google-cloud-core-http;2.47.0 in central
# 	found com.google.http-client#google-http-client-appengine;1.45.0 in central
# 	found com.google.api#gax-httpjson;2.57.0 in central
# 	found com.google.cloud#google-cloud-core-grpc;2.47.0 in central
# 	found com.google.api#gax;2.57.0 in central
# 	found com.google.api#gax-grpc;2.54.1 in central
# 	found io.grpc#grpc-inprocess;1.67.1 in central
# 	found com.google.api#api-common;2.40.0 in central
# 	found javax.annotation#javax.annotation-api;1.3.2 in central
# 	found io.grpc#grpc-protobuf-lite;1.67.1 in central
# 	found com.google.api.grpc#proto-google-common-protos;2.48.0 in central
# 	found com.google.api.grpc#proto-google-cloud-storage-v2;2.44.1-beta in central
# 	found com.google.api.grpc#grpc-google-cloud-storage-v2;2.44.1-beta in central
# 	found com.google.api.grpc#gapic-google-cloud-storage-v2;2.44.1-beta in central
# 	found io.opentelemetry#opentelemetry-sdk;1.42.1 in central
# 	found io.opentelemetry#opentelemetry-sdk-trace;1.42.1 in central
# 	found io.opentelemetry#opentelemetry-sdk-logs;1.42.1 in central
# 	found io.grpc#grpc-opentelemetry;1.67.1 in central
# 	found io.opentelemetry#opentelemetry-api;1.42.1 in central
# 	found io.opentelemetry#opentelemetry-context;1.42.1 in central
# 	found io.opentelemetry#opentelemetry-sdk-metrics;1.42.1 in central
# 	found io.opentelemetry#opentelemetry-sdk-common;1.42.1 in central
# 	found io.opentelemetry#opentelemetry-sdk-extension-autoconfigure-spi;1.42.1 in central
# 	found io.opentelemetry.semconv#opentelemetry-semconv;1.25.0-alpha in central
# 	found com.google.cloud.opentelemetry#exporter-metrics;0.31.0 in central
# 	found org.slf4j#slf4j-api;2.0.9 in central
# 	found com.google.cloud#google-cloud-monitoring;3.31.0 in central
# 	found com.google.api.grpc#proto-google-cloud-monitoring-v3;3.31.0 in central
# 	found io.opentelemetry.contrib#opentelemetry-gcp-resources;1.37.0-alpha in central
# 	found org.checkerframework#checker-qual;3.47.0 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.18.0 in central
# 	found com.google.cloud#google-cloud-storage-control;2.44.1 in central
# 	found com.google.api.grpc#proto-google-cloud-storage-control-v2;2.44.1 in central
# 	found com.google.api.grpc#grpc-google-cloud-storage-control-v2;2.44.1 in central
# 	found io.grpc#grpc-xds;1.67.1 in central
# 	found io.grpc#grpc-util;1.67.1 in central
# 	found io.grpc#grpc-services;1.67.1 in central
# 	found com.google.re2j#re2j;1.7 in central
# 	found io.opencensus#opencensus-impl;0.31.0 in central
# 	found io.opencensus#opencensus-impl-core;0.31.0 in central
# 	found com.lmax#disruptor;3.4.2 in central
# 	found io.opencensus#opencensus-exporter-stats-stackdriver;0.31.0 in central
# 	found io.opencensus#opencensus-contrib-exemplar-util;0.31.0 in central
# 	found io.opencensus#opencensus-contrib-resource-util;0.31.0 in central
# 	found io.opencensus#opencensus-exporter-metrics-util;0.31.0 in central
# 	found io.opencensus#opencensus-contrib-grpc-metrics;0.31.0 in central
# 	found com.google.android#annotations;4.1.1.4 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.24 in central
# 	found io.perfmark#perfmark-api;0.27.0 in central
# 	found io.opentelemetry#opentelemetry-api-incubator;1.42.1-alpha in central
# 	found io.opencensus#opencensus-proto;0.2.0 in central
# 	found com.google.cloud.opentelemetry#shared-resourcemapping;0.32.0 in central
# 	found com.google.cloud.opentelemetry#detector-resources-support;0.32.0 in central
# 	found io.grpc#grpc-googleapis;1.67.1 in central
# 	found io.grpc#grpc-rls;1.67.1 in central
# :: resolution report :: resolve 1348ms :: artifacts dl 18ms
# 	:: modules in use:
# 	com.fasterxml.jackson.core#jackson-core;2.18.0 from central in [default]
# 	com.google.android#annotations;4.1.1.4 from central in [default]
# 	com.google.api#api-common;2.40.0 from central in [default]
# 	com.google.api#gax;2.57.0 from central in [default]
# 	com.google.api#gax-grpc;2.54.1 from central in [default]
# 	com.google.api#gax-httpjson;2.57.0 from central in [default]
# 	com.google.api-client#google-api-client;2.7.0 from central in [default]
# 	com.google.api-client#google-api-client-jackson2;2.0.1 from central in [default]
# 	com.google.api.grpc#gapic-google-cloud-storage-v2;2.44.1-beta from central in [default]
# 	com.google.api.grpc#grpc-google-cloud-storage-control-v2;2.44.1 from central in [default]
# 	com.google.api.grpc#grpc-google-cloud-storage-v2;2.44.1-beta from central in [default]
# 	com.google.api.grpc#proto-google-cloud-monitoring-v3;3.31.0 from central in [default]
# 	com.google.api.grpc#proto-google-cloud-storage-control-v2;2.44.1 from central in [default]
# 	com.google.api.grpc#proto-google-cloud-storage-v2;2.44.1-beta from central in [default]
# 	com.google.api.grpc#proto-google-common-protos;2.48.0 from central in [default]
# 	com.google.api.grpc#proto-google-iam-v1;1.1.7 from central in [default]
# 	com.google.apis#google-api-services-iamcredentials;v1-rev20211203-2.0.0 from central in [default]
# 	com.google.apis#google-api-services-storage;v1-rev20240105-2.0.0 from central in [default]
# 	com.google.auth#google-auth-library-credentials;1.29.0 from central in [default]
# 	com.google.auth#google-auth-library-oauth2-http;1.29.0 from central in [default]
# 	com.google.auto.value#auto-value-annotations;1.10.4 from central in [default]
# 	com.google.cloud#google-cloud-core;2.44.1 from central in [default]
# 	com.google.cloud#google-cloud-core-grpc;2.47.0 from central in [default]
# 	com.google.cloud#google-cloud-core-http;2.47.0 from central in [default]
# 	com.google.cloud#google-cloud-monitoring;3.31.0 from central in [default]
# 	com.google.cloud#google-cloud-storage;2.44.1 from central in [default]
# 	com.google.cloud#google-cloud-storage-control;2.44.1 from central in [default]
# 	com.google.cloud.bigdataoss#gcs-connector;hadoop3-2.2.27 from central in [default]
# 	com.google.cloud.bigdataoss#gcsio;2.2.27 from central in [default]
# 	com.google.cloud.bigdataoss#util;2.2.27 from central in [default]
# 	com.google.cloud.bigdataoss#util-hadoop;hadoop3-2.2.27 from central in [default]
# 	com.google.cloud.opentelemetry#detector-resources-support;0.32.0 from central in [default]
# 	com.google.cloud.opentelemetry#exporter-metrics;0.31.0 from central in [default]
# 	com.google.cloud.opentelemetry#shared-resourcemapping;0.32.0 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.8.9 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.35.1 from central in [default]
# 	com.google.flogger#flogger;0.7.1 from central in [default]
# 	com.google.flogger#flogger-system-backend;0.7.1 from central in [default]
# 	com.google.flogger#google-extensions;0.7.1 from central in [default]
# 	com.google.guava#failureaccess;1.0.2 from central in [default]
# 	com.google.guava#guava;33.1.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.http-client#google-http-client;1.45.0 from central in [default]
# 	com.google.http-client#google-http-client-apache-v2;1.45.0 from central in [default]
# 	com.google.http-client#google-http-client-appengine;1.45.0 from central in [default]
# 	com.google.http-client#google-http-client-gson;1.45.0 from central in [default]
# 	com.google.http-client#google-http-client-jackson2;1.42.3 from central in [default]
# 	com.google.j2objc#j2objc-annotations;3.0.0 from central in [default]
# 	com.google.oauth-client#google-oauth-client;1.34.1 from central in [default]
# 	com.google.protobuf#protobuf-java;3.25.3 from central in [default]
# 	com.google.protobuf#protobuf-java-util;3.25.3 from central in [default]
# 	com.google.re2j#re2j;1.7 from central in [default]
# 	com.lmax#disruptor;3.4.2 from central in [default]
# 	commons-codec#commons-codec;1.17.1 from central in [default]
# 	commons-logging#commons-logging;1.2 from central in [default]
# 	io.grpc#grpc-alts;1.67.1 from central in [default]
# 	io.grpc#grpc-api;1.67.1 from central in [default]
# 	io.grpc#grpc-auth;1.67.1 from central in [default]
# 	io.grpc#grpc-census;1.67.1 from central in [default]
# 	io.grpc#grpc-context;1.67.1 from central in [default]
# 	io.grpc#grpc-core;1.67.1 from central in [default]
# 	io.grpc#grpc-googleapis;1.67.1 from central in [default]
# 	io.grpc#grpc-grpclb;1.67.1 from central in [default]
# 	io.grpc#grpc-inprocess;1.67.1 from central in [default]
# 	io.grpc#grpc-netty-shaded;1.67.1 from central in [default]
# 	io.grpc#grpc-opentelemetry;1.67.1 from central in [default]
# 	io.grpc#grpc-protobuf;1.67.1 from central in [default]
# 	io.grpc#grpc-protobuf-lite;1.67.1 from central in [default]
# 	io.grpc#grpc-rls;1.67.1 from central in [default]
# 	io.grpc#grpc-services;1.67.1 from central in [default]
# 	io.grpc#grpc-stub;1.67.1 from central in [default]
# 	io.grpc#grpc-util;1.67.1 from central in [default]
# 	io.grpc#grpc-xds;1.67.1 from central in [default]
# 	io.opencensus#opencensus-api;0.31.1 from central in [default]
# 	io.opencensus#opencensus-contrib-exemplar-util;0.31.0 from central in [default]
# 	io.opencensus#opencensus-contrib-grpc-metrics;0.31.0 from central in [default]
# 	io.opencensus#opencensus-contrib-http-util;0.31.1 from central in [default]
# 	io.opencensus#opencensus-contrib-resource-util;0.31.0 from central in [default]
# 	io.opencensus#opencensus-exporter-metrics-util;0.31.0 from central in [default]
# 	io.opencensus#opencensus-exporter-stats-stackdriver;0.31.0 from central in [default]
# 	io.opencensus#opencensus-impl;0.31.0 from central in [default]
# 	io.opencensus#opencensus-impl-core;0.31.0 from central in [default]
# 	io.opencensus#opencensus-proto;0.2.0 from central in [default]
# 	io.opentelemetry#opentelemetry-api;1.42.1 from central in [default]
# 	io.opentelemetry#opentelemetry-api-incubator;1.42.1-alpha from central in [default]
# 	io.opentelemetry#opentelemetry-context;1.42.1 from central in [default]
# 	io.opentelemetry#opentelemetry-sdk;1.42.1 from central in [default]
# 	io.opentelemetry#opentelemetry-sdk-common;1.42.1 from central in [default]
# 	io.opentelemetry#opentelemetry-sdk-extension-autoconfigure-spi;1.42.1 from central in [default]
# 	io.opentelemetry#opentelemetry-sdk-logs;1.42.1 from central in [default]
# 	io.opentelemetry#opentelemetry-sdk-metrics;1.42.1 from central in [default]
# 	io.opentelemetry#opentelemetry-sdk-trace;1.42.1 from central in [default]
# 	io.opentelemetry.contrib#opentelemetry-gcp-resources;1.37.0-alpha from central in [default]
# 	io.opentelemetry.semconv#opentelemetry-semconv;1.25.0-alpha from central in [default]
# 	io.perfmark#perfmark-api;0.27.0 from central in [default]
# 	javax.annotation#javax.annotation-api;1.3.2 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.13 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.16 from central in [default]
# 	org.checkerframework#checker-compat-qual;2.5.3 from central in [default]
# 	org.checkerframework#checker-qual;3.47.0 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.24 from central in [default]
# 	org.conscrypt#conscrypt-openjdk-uber;2.5.2 from central in [default]
# 	org.slf4j#slf4j-api;2.0.9 from central in [default]
# 	org.threeten#threetenbp;1.7.0 from central in [default]
# 	:: evicted modules:
# 	com.google.api-client#google-api-client;2.0.1 by [com.google.api-client#google-api-client;2.2.0] in [default]
# 	com.google.http-client#google-http-client;1.42.3 by [com.google.http-client#google-http-client;1.45.0] in [default]
# 	org.apache.httpcomponents#httpcore;4.4.15 by [org.apache.httpcomponents#httpcore;4.4.16] in [default]
# 	commons-codec#commons-codec;1.15 by [commons-codec#commons-codec;1.17.1] in [default]
# 	com.google.errorprone#error_prone_annotations;2.16 by [com.google.errorprone#error_prone_annotations;2.34.0] in [default]
# 	org.checkerframework#checker-qual;3.42.0 by [org.checkerframework#checker-qual;3.47.0] in [default]
# 	com.google.j2objc#j2objc-annotations;1.3 by [com.google.j2objc#j2objc-annotations;3.0.0] in [default]
# 	com.google.http-client#google-http-client-gson;1.42.3 by [com.google.http-client#google-http-client-gson;1.45.0] in [default]
# 	com.google.http-client#google-http-client-apache-v2;1.42.3 by [com.google.http-client#google-http-client-apache-v2;1.45.0] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.13.4 by [com.fasterxml.jackson.core#jackson-core;2.18.0] in [default]
# 	com.google.api-client#google-api-client;2.0.0 by [com.google.api-client#google-api-client;2.2.0] in [default]
# 	com.google.api-client#google-api-client;2.2.0 by [com.google.api-client#google-api-client;2.7.0] in [default]
# 	com.google.errorprone#error_prone_annotations;2.34.0 by [com.google.errorprone#error_prone_annotations;2.32.0] in [default]
# 	com.google.api.grpc#proto-google-common-protos;2.41.0 by [com.google.api.grpc#proto-google-common-protos;2.48.0] in [default]
# 	com.google.api#gax;2.54.1 by [com.google.api#gax;2.57.0] in [default]
# 	com.google.errorprone#error_prone_annotations;2.32.0 by [com.google.errorprone#error_prone_annotations;2.35.1] in [default]
# 	com.google.api.grpc#proto-google-common-protos;2.45.1 by [com.google.api.grpc#proto-google-common-protos;2.48.0] in [default]
# 	com.google.api#api-common;2.37.1 by [com.google.api#api-common;2.40.0] in [default]
# 	io.grpc#grpc-inprocess;1.68.0 by [io.grpc#grpc-inprocess;1.67.1] in [default]
# 	io.opencensus#opencensus-api;0.31.0 by [io.opencensus#opencensus-api;0.31.1] in [default]
# 	com.google.cloud#google-cloud-monitoring;1.82.0 by [com.google.cloud#google-cloud-monitoring;3.31.0] in [default]
# 	com.google.errorprone#error_prone_annotations;2.28.0 by [com.google.errorprone#error_prone_annotations;2.35.1] in [default]
# 	com.google.errorprone#error_prone_annotations;2.18.0 by [com.google.errorprone#error_prone_annotations;2.28.0] in [default]
# 	com.google.j2objc#j2objc-annotations;2.8 by [com.google.j2objc#j2objc-annotations;3.0.0] in [default]
# 	io.grpc#grpc-googleapis;1.68.0 by [io.grpc#grpc-googleapis;1.67.1] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  130  |   0   |   0   |   25  ||  105  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-b2a32b67-6b54-4007-9e14-a8b7971b3d60
# 	confs: [default]
# 	0 artifacts copied, 105 already retrieved (0kB/12ms)
# 26/03/05 19:44:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/05 19:44:38 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# http://5e051a57d6c4:4041
# [Stage 1:>                                                          (0 + 1) / 1]
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+------------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|Airport_fee|cbd_congestion_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+------------------+
# |       7| 2025-11-01 00:13:25|  2025-11-01 00:13:25|              1|         1.68|         1|                 N|          43|         186|           1|       14.9|  0.0|    0.5|       1.5|         0.0|                  1.0|       22.15|                 2.5|        0.0|              0.75|
# |       2| 2025-11-01 00:49:07|  2025-11-01 01:01:22|              1|         2.28|         1|                 N|         142|         237|           1|       14.2|  1.0|    0.5|      4.99|         0.0|                  1.0|       24.94|                 2.5|        0.0|              0.75|
# |       1| 2025-11-01 00:07:19|  2025-11-01 00:20:41|              0|          2.7|         1|                 N|         163|         238|           1|       15.6| 4.25|    0.5|      4.27|         0.0|                  1.0|       25.62|                 2.5|        0.0|              0.75|
# |       2| 2025-11-01 00:00:00|  2025-11-01 01:01:03|              3|        12.87|         1|                 N|         138|         261|           1|       66.7|  6.0|    0.5|       0.0|        6.94|                  1.0|       86.14|                 2.5|       1.75|              0.75|
# |       1| 2025-11-01 00:18:50|  2025-11-01 00:49:32|              0|          8.4|         1|                 N|         138|          37|           2|       39.4| 7.75|    0.5|       0.0|         0.0|                  1.0|       48.65|                 0.0|       1.75|               0.0|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+------------------+
